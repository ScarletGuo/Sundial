# %%
import pandas as pd
import matplotlib
import sys
# print(sys.argv[1])
name='pr_08_25_all'
df = pd.read_csv(name+'.csv')

# %%
grouped = df.groupby(['COMMIT_ALG', 'PERC_REMOTE'])
newdf = grouped['Throughput'].mean().reset_index()
newdf = newdf.pivot(index='PERC_REMOTE', columns='COMMIT_ALG', values='Throughput')
print(newdf)
plot = newdf.plot()
plot.set_ylabel("Throughput")
plot.set_xlabel("PERC_REMOTE")
plot.set_ylim(bottom=0)
fig = plot.get_figure()
fig.savefig(name+".png")
# Out:
# COMMIT_ALG     ONE_PC    TWO_PC
# PERC_REMOTE
# 0.1          7681.597  4823.418

# %%
latency = grouped['average_latency', 'average_local_latency', 'average_distributed_latency'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-15-6e4f263a5f2d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['average_latency', 'average_local_latency', 'average_distributed_latency'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.savefig(name+"_latency.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  average_latency  average_local_latency  \
# 0     ONE_PC          0.1         0.003343               0.001004
# 1     TWO_PC          0.1         0.004322               0.000926
#
#    average_distributed_latency
# 0                     0.005189
# 1                     0.006919

# %%
latency = grouped['execute_phase (in us)', 'prepare_phase (in us)','commit_phase (in us)', 'abort (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-17-2ee0c6eec36f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['execute_phase (in us)', 'prepare_phase (in us)','commit_phase (in us)', 'abort (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  execute_phase (in us)  prepare_phase (in us)  \
# 0     ONE_PC          0.1               462.8141               2872.335
# 1     TWO_PC          0.1               427.5889               2792.093
#
#    commit_phase (in us)  abort (in us)
# 0              7.195931       0.777325
# 1           1100.739000       1.166942

# %%
latency = grouped['execute_phase_local (in us)', 'prepare_phase_local (in us)','commit_phase_local (in us)', 'abort_local (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-19-9b700c6480bd>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['execute_phase_local (in us)', 'prepare_phase_local (in us)','commit_phase_local (in us)', 'abort_local (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  execute_phase_local (in us)  \
# 0     ONE_PC          0.1                    140.34912
# 1     TWO_PC          0.1                    151.40249
#
#    prepare_phase_local (in us)  commit_phase_local (in us)  \
# 0                     2226.233                    6.328048
# 1                     2078.051                    5.671892
#
#    abort_local (in us)
# 0             0.890966
# 1             2.046015

# %%
latency = grouped['execute_phase_dist_readonly (in us)', 'prepare_phase_dist_readonly (in us)','commit_phase_dist_readonly (in us)', 'abort_dist_readonly (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-21-1145704f247d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['execute_phase_dist_readonly (in us)', 'prepare_phase_dist_readonly (in us)','commit_phase_dist_readonly (in us)', 'abort_dist_readonly (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  execute_phase_dist_readonly (in us)  \
# 0     ONE_PC          0.1                             531.4476
# 1     TWO_PC          0.1                             496.1284
#
#    prepare_phase_dist_readonly (in us)  commit_phase_dist_readonly (in us)  \
# 0                             3029.336                            6.071781
# 1                             2948.294                            5.654527
#
#    abort_dist_readonly (in us)
# 0                            0
# 1                            0

# %%
latency = grouped['execute_phase_dist_write (in us)', 'prepare_phase_dist_write (in us)','commit_phase_dist_write (in us)', 'abort_dist_write (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-23-5dc6a36c019c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['execute_phase_dist_write (in us)', 'prepare_phase_dist_write (in us)','commit_phase_dist_write (in us)', 'abort_dist_write (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  execute_phase_dist_write (in us)  \
# 0     ONE_PC          0.1                          539.2524
# 1     TWO_PC          0.1                          484.1881
#
#    prepare_phase_dist_write (in us)  commit_phase_dist_write (in us)  \
# 0                          3016.668                         7.997695
# 1                          2947.887                      1939.218000
#
#    abort_dist_write (in us)
# 0                  1.094543
# 1                  1.407992

# %%
latency = grouped['network_log (in us)', 'total_log_yes (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-25-f9d8dc48aa43>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['network_log (in us)', 'total_log_yes (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
# fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  network_log (in us)  total_log_yes (in us)
# 0     ONE_PC          0.1             997.8654               2298.890
# 1     TWO_PC          0.1            1929.0260               2122.416

# %%
latency = grouped['network_log (in us)', 'total_log_yes (in us)'].mean().reset_index()
result = latency[latency['PERC_REMOTE'] == 0.1]
# Out:
# <ipython-input-27-f9d8dc48aa43>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   latency = grouped['network_log (in us)', 'total_log_yes (in us)'].mean().reset_index()

# %%
print(result)
result = result.drop(['PERC_REMOTE'], axis=1)
latency_plot = result.plot.bar(stacked='True', x='COMMIT_ALG')
fig = latency_plot.get_figure()
fig.set_size_inches(10, 5)
# fig.savefig(name+"_phase_breakdown.png")
# Out:
#   COMMIT_ALG  PERC_REMOTE  network_log (in us)  total_log_yes (in us)
# 0     ONE_PC          0.1             997.8654               2298.890
# 1     TWO_PC          0.1            1929.0260               2122.416
